# %%
import pandas as pd
import numpy as np
import sklearn

# %%
chunks = []
for chunk in pd.read_csv(filepath_or_buffer='data\\title.basics.tsv', sep='\t', chunksize=10000):
    filtered_chunk = chunk[chunk['titleType'] == 'movie']
    chunks.append(filtered_chunk)

title = pd.concat(chunks, ignore_index=True)
