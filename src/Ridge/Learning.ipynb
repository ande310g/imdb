# %%
import pandas as pd
import numpy as np
import joblib
import os
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV, TimeSeriesSplit
from scipy.stats import randint, uniform
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## Variables

# %%
cols_to_drop = ['Unnamed: 0', 'averageRating', 'numVotes', '_orig_order']

# %% [markdown]
# ### Retrieve data

# %%
train_dataset_path = os.path.join('..', '..', 'data', 'training_dataset.csv')
df = pd.read_csv(train_dataset_path, sep=";")
df = df.sort_values(by=['startYear', '_orig_order'])
df = df.drop(columns=cols_to_drop)
y = np.expm1(df["movie_score"].values)
X = df.drop(columns=["movie_score"])

# %% [markdown]
# ### Train the best model with parameters and save it.

# %%
ridge = Ridge(max_iter=1000)
param_grid_ridge = {
    'alpha': np.logspace(-6, 3, 19)
}
ridge_grid_search = GridSearchCV(ridge, param_grid_ridge, cv=5, scoring='r2', n_jobs=-1)
ridge_grid_search.fit(X, y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.83175e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.20093e-18): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.50822e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.96031e-19): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.05791e-18): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.7898e-18): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.95984e-18): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.79339e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.50751e-18): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.48138e-18): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.20088e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.05784e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.83148e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.50743e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.49066e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.9598e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# ['Linear_Regression_Ridge.joblib']

# %%
print(ridge_grid_search.best_estimator_)
print(ridge_grid_search.best_score_)
print(ridge_grid_search.best_params_)
# Out:
# Ridge(alpha=np.float64(1000.0), max_iter=1000)
# -0.6617716391357391
# {'alpha': np.float64(1000.0)}

# %%
joblib.dump(ridge_grid_search.best_estimator_, "Linear_Regression_Ridge.joblib")
