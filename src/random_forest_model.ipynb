# %% [markdown]
# # Random Forest Model for Movie Score Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from scipy.stats import randint, uniform

# %% [markdown]
# ## Load Training Dataset

# %%
useBackslash = False
trainingDatasetPath = r'..\data\training_dataset.csv' if useBackslash else r'../data/training_dataset.csv'
dataset_training = pd.read_csv(trainingDatasetPath, sep=';')

# %%
print(dataset_training.columns.tolist())
# Out:
# ['Unnamed: 0', 'isAdult', 'startYear', 'runtimeMinutes', 'averageRating', 'numVotes', 'movie_score', '_orig_order', 'prior_movie_director_sentiment', 'prior1_rating_director', 'prior2_rating_director', 'prior3_rating_director', 'actor1_prior1_rating_actor', 'actor1_prior2_rating_actor', 'actor1_prior3_rating_actor', 'actor1_prior_movie_actor_sentiment', 'actor2_prior1_rating_actor', 'actor2_prior2_rating_actor', 'actor2_prior3_rating_actor', 'actor2_prior_movie_actor_sentiment', 'actor3_prior1_rating_actor', 'actor3_prior2_rating_actor', 'actor3_prior3_rating_actor', 'actor3_prior_movie_actor_sentiment', 'actor4_prior1_rating_actor', 'actor4_prior2_rating_actor', 'actor4_prior3_rating_actor', 'actor4_prior_movie_actor_sentiment', 'actor5_prior1_rating_actor', 'actor5_prior2_rating_actor', 'actor5_prior3_rating_actor', 'actor5_prior_movie_actor_sentiment', 'actor6_prior1_rating_actor', 'actor6_prior2_rating_actor', 'actor6_prior3_rating_actor', 'actor6_prior_movie_actor_sentiment', 'actor7_prior1_rating_actor', 'actor7_prior2_rating_actor', 'actor7_prior3_rating_actor', 'actor7_prior_movie_actor_sentiment', 'actor8_prior1_rating_actor', 'actor8_prior2_rating_actor', 'actor8_prior3_rating_actor', 'actor8_prior_movie_actor_sentiment', 'actor9_prior1_rating_actor', 'actor9_prior2_rating_actor', 'actor9_prior3_rating_actor', 'actor9_prior_movie_actor_sentiment', 'actor10_prior1_rating_actor', 'actor10_prior2_rating_actor', 'actor10_prior3_rating_actor', 'actor10_prior_movie_actor_sentiment', 'genre_1_Action', 'genre_1_Adult', 'genre_1_Adventure', 'genre_1_Animation', 'genre_1_Biography', 'genre_1_Comedy', 'genre_1_Crime', 'genre_1_Documentary', 'genre_1_Drama', 'genre_1_Family', 'genre_1_Fantasy', 'genre_1_Film-Noir', 'genre_1_History', 'genre_1_Horror', 'genre_1_Music', 'genre_1_Musical', 'genre_1_Mystery', 'genre_1_Reality-TV', 'genre_1_Romance', 'genre_1_Sci-Fi', 'genre_1_Sport', 'genre_1_Thriller', 'genre_1_War', 'genre_1_Western', 'genre_1_\\N', 'genre_2_Adult', 'genre_2_Adventure', 'genre_2_Animation', 'genre_2_Biography', 'genre_2_Comedy', 'genre_2_Crime', 'genre_2_Documentary', 'genre_2_Drama', 'genre_2_Family', 'genre_2_Fantasy', 'genre_2_Film-Noir', 'genre_2_History', 'genre_2_Horror', 'genre_2_Music', 'genre_2_Musical', 'genre_2_Mystery', 'genre_2_News', 'genre_2_Reality-TV', 'genre_2_Romance', 'genre_2_Sci-Fi', 'genre_2_Sport', 'genre_2_Thriller', 'genre_2_War', 'genre_2_Western', 'genre_2_nan', 'genre_3_Adventure', 'genre_3_Animation', 'genre_3_Biography', 'genre_3_Comedy', 'genre_3_Crime', 'genre_3_Documentary', 'genre_3_Drama', 'genre_3_Family', 'genre_3_Fantasy', 'genre_3_Film-Noir', 'genre_3_History', 'genre_3_Horror', 'genre_3_Music', 'genre_3_Musical', 'genre_3_Mystery', 'genre_3_News', 'genre_3_Reality-TV', 'genre_3_Romance', 'genre_3_Sci-Fi', 'genre_3_Sport', 'genre_3_Talk-Show', 'genre_3_Thriller', 'genre_3_War', 'genre_3_Western', 'genre_3_nan', 'runtime_category_long', 'runtime_category_medium', 'runtime_category_short', 'runtime_category_very_long']

# %% [markdown]
# ## Load Test Dataset

# %%
useBackslash = False
testDatasetPath = r'..\data\test_dataset.csv' if useBackslash else r'../data/test_dataset.csv'
df_test = pd.read_csv(testDatasetPath, sep=";")

# %% [markdown]
# ## Prepare Training Data

# %%
y_train = np.log1p(dataset_training['movie_score'].values)
dataset_training = dataset_training.drop(columns=['movie_score', 'Unnamed: 0', 'averageRating', 'numVotes', '_orig_order'])
x_train = dataset_training.values

# %% [markdown]
# ## Prepare Test Data

# %%
y_test = np.log1p(df_test['movie_score'].values)
df_test = df_test.drop(columns=['movie_score', 'Unnamed: 0', 'averageRating', 'numVotes', '_orig_order'])
x_test = df_test.values

# %% [markdown]
# ## Create and Train Basic Random Forest Model

# %%
# Creating and training a basic random forest model
rf_basic = RandomForestRegressor(
    n_estimators=100,
    random_state=42,
    n_jobs=-1,
    verbose=1
)
rf_basic.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  1.3min finished
# RandomForestRegressor(n_jobs=-1, random_state=42, verbose=1)

# %%
# Evaluate basic model
y_train_pred = rf_basic.predict(x_train)
y_test_pred = rf_basic.predict(x_test)

print("Basic Random Forest Model Performance:")
print(f"Training R²: {r2_score(y_train, y_train_pred):.3f}")
print(f"Test R²: {r2_score(y_test, y_test_pred):.3f}")
print(f"Training RMSE: {np.sqrt(mean_squared_error(y_train, y_train_pred)):.3f}")
print(f"Test RMSE: {np.sqrt(mean_squared_error(y_test, y_test_pred)):.3f}")
print(f"Training MAE: {mean_absolute_error(y_train, y_train_pred):.3f}")
print(f"Test MAE: {mean_absolute_error(y_test, y_test_pred):.3f}")
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    0.4s
# Basic Random Forest Model Performance:
# Training R²: 0.932
# Test R²: 0.437
# Training RMSE: 0.466
# Test RMSE: 1.256
# Training MAE: 0.355
# Test MAE: 0.996
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.9s finished
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=10)]: Done 100 out of 100 | elapsed:    0.2s finished

# %%
x_train.shape
# Out:
# (114962, 126)

# %% [markdown]
# ## Hyperparameter Tuning with RandomizedSearchCV

# %%
# Random Forest with RandomizedSearchCV (much faster than GridSearchCV)
rf = RandomForestRegressor(random_state=42, n_jobs=-1, max_samples=0.8, verbose=0)

# Optimized parameter distributions for faster search
param_dist_rf = {
    'n_estimators': [300, 400],
    'max_depth': [10, 20, 30, 40],
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(2, 15),
    'max_features': ['sqrt', 'log2']
}

rf_random_search = RandomizedSearchCV(
    rf,
    param_distributions=param_dist_rf,
    n_iter=30,  # Reduced from 50 for faster execution
    cv=5,
    scoring='r2',
    n_jobs=1,
    verbose=2,
    random_state=42
)
rf_random_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=14, min_samples_split=16, n_estimators=300; total time=   6.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=14, min_samples_split=16, n_estimators=300; total time=   7.1s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=14, min_samples_split=16, n_estimators=300; total time=   6.9s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=14, min_samples_split=16, n_estimators=300; total time=   6.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=14, min_samples_split=16, n_estimators=300; total time=   6.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=400; total time=  14.8s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=400; total time=  17.0s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=400; total time=  16.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=400; total time=  16.7s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=400; total time=  17.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=12, n_estimators=400; total time=  13.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=12, n_estimators=400; total time=  16.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=12, n_estimators=400; total time=  15.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=12, n_estimators=400; total time=  14.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=12, n_estimators=400; total time=  15.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=400; total time=   5.8s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=400; total time=   5.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=400; total time=   6.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=400; total time=   5.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=400; total time=   6.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=400; total time=   5.3s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=400; total time=   6.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=400; total time=   6.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=400; total time=   5.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=400; total time=   5.7s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=13, min_samples_split=2, n_estimators=400; total time=   7.4s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=13, min_samples_split=2, n_estimators=400; total time=   7.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=13, min_samples_split=2, n_estimators=400; total time=   8.9s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=13, min_samples_split=2, n_estimators=400; total time=   8.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=13, min_samples_split=2, n_estimators=400; total time=   9.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=14, min_samples_split=13, n_estimators=300; total time=   5.5s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=14, min_samples_split=13, n_estimators=300; total time=   5.8s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=14, min_samples_split=13, n_estimators=300; total time=   5.9s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=14, min_samples_split=13, n_estimators=300; total time=   6.0s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=14, min_samples_split=13, n_estimators=300; total time=   5.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=12, min_samples_split=11, n_estimators=400; total time=   8.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=12, min_samples_split=11, n_estimators=400; total time=   9.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=12, min_samples_split=11, n_estimators=400; total time=   9.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=12, min_samples_split=11, n_estimators=400; total time=   9.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=12, min_samples_split=11, n_estimators=400; total time=   8.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=13, n_estimators=300; total time=   6.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=13, n_estimators=300; total time=   6.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=13, n_estimators=300; total time=   6.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=13, n_estimators=300; total time=   7.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=13, n_estimators=300; total time=   7.3s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   5.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   6.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   6.5s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   6.6s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=10, min_samples_split=4, n_estimators=300; total time=   7.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=300; total time=  11.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=300; total time=  10.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=300; total time=  11.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=300; total time=  12.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=300; total time=  13.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=400; total time=   8.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=400; total time=   7.7s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=400; total time=   7.7s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=400; total time=   8.2s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=400; total time=   7.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=11, min_samples_split=3, n_estimators=400; total time=  11.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=11, min_samples_split=3, n_estimators=400; total time=  11.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=11, min_samples_split=3, n_estimators=400; total time=  12.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=11, min_samples_split=3, n_estimators=400; total time=  12.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=11, min_samples_split=3, n_estimators=400; total time=  12.8s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=13, min_samples_split=8, n_estimators=400; total time=  15.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=13, min_samples_split=8, n_estimators=400; total time=  14.0s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=13, min_samples_split=8, n_estimators=400; total time=  15.2s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=13, min_samples_split=8, n_estimators=400; total time=  13.8s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=13, min_samples_split=8, n_estimators=400; total time=  14.3s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time=   5.6s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time=   4.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time=   4.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time=   3.8s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time=   4.1s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=9, min_samples_split=5, n_estimators=400; total time=   9.9s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=9, min_samples_split=5, n_estimators=400; total time=   8.6s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=9, min_samples_split=5, n_estimators=400; total time=   8.7s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=9, min_samples_split=5, n_estimators=400; total time=   8.2s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=9, min_samples_split=5, n_estimators=400; total time=   7.8s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=400; total time=   7.7s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=400; total time=   7.9s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=400; total time=   8.0s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=400; total time=   8.2s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=400; total time=   8.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=  13.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=  15.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=  20.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=  15.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=400; total time=  15.3s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   5.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   6.2s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   6.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   6.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   7.8s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=15, n_estimators=300; total time=  10.9s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=15, n_estimators=300; total time=  10.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=15, n_estimators=300; total time=  10.9s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=15, n_estimators=300; total time=  11.8s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=15, n_estimators=300; total time=  10.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=17, n_estimators=300; total time=   9.8s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=17, n_estimators=300; total time=  10.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=17, n_estimators=300; total time=  11.0s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=17, n_estimators=300; total time=  11.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=9, min_samples_split=17, n_estimators=300; total time=  10.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=300; total time=  10.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=300; total time=  10.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=300; total time=  11.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=300; total time=  10.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=300; total time=  10.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=300; total time=   6.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=300; total time=   7.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=300; total time=   6.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=300; total time=   7.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=300; total time=   6.6s

# %%
# Inspect best Random Forest parameters and scores
best_params_rf = rf_random_search.best_params_
best_rf = rf_random_search.best_estimator_

print(f"Best Random Forest parameters: {best_params_rf}")
print(f"Best Random Forest CV R-squared: {rf_random_search.best_score_:.3f}")
print(f"Best Random Forest training R-squared: {best_rf.score(x_train, y_train):.3f}")
print(f"Best Random Forest test R-squared: {best_rf.score(x_test, y_test):.3f}")

# Additional metrics
y_train_pred_best = best_rf.predict(x_train)
y_test_pred_best = best_rf.predict(x_test)

print(f"\nBest Random Forest Model Performance:")
print(f"Training RMSE: {np.sqrt(mean_squared_error(y_train, y_train_pred_best)):.3f}")
print(f"Test RMSE: {np.sqrt(mean_squared_error(y_test, y_test_pred_best)):.3f}")
print(f"Training MAE: {mean_absolute_error(y_train, y_train_pred_best):.3f}")
print(f"Test MAE: {mean_absolute_error(y_test, y_test_pred_best):.3f}")
#Best Random Forest parameters: {'max_depth': 30, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 400}
# Out:
# Best Random Forest parameters: {'max_depth': 30, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 400}
# Best Random Forest CV R-squared: 0.268
# Best Random Forest training R-squared: 0.688
# Best Random Forest test R-squared: -0.101
#
# Best Random Forest Model Performance:
# Training RMSE: 274693.094
# Test RMSE: 226519.410
# Training MAE: 46918.245
# Test MAE: 60953.228

# %% [markdown]
# ## Feature Importance Analysis

# %%
# Get feature importances from the best model
feature_importances = best_rf.feature_importances_
feature_names = dataset_training.columns

# Create a DataFrame for easier visualization
importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': feature_importances
}).sort_values('importance', ascending=False)

# Display top 20 most important features
print("Top 20 Most Important Features:")
print(importance_df.head(20))

# %%
# Visualize top 20 feature importances
plt.figure(figsize=(10, 8))
top_features = importance_df.head(20)
plt.barh(range(len(top_features)), top_features['importance'])
plt.yticks(range(len(top_features)), top_features['feature'])
plt.xlabel('Feature Importance')
plt.title('Top 20 Feature Importances - Random Forest')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Save the Best Model

# %%
# Save the best model
joblib.dump(best_rf, "random_forest_movie_score.joblib")
print("Model saved as 'random_forest_movie_score.joblib'")

# %% [markdown]
# ## Cross-Validation Score

# %%
# Perform cross-validation on the best model
cv_scores = cross_val_score(best_rf, x_train, y_train, cv=10, scoring='r2', n_jobs=-1)
print(f"Cross-validation R² scores: {cv_scores}")
print(f"Mean CV R²: {cv_scores.mean():.3f} (+/- {cv_scores.std() * 2:.3f})")
